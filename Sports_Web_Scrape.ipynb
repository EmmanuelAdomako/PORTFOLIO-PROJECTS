# %%
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_sports_contracts'
tables = pd.read_html(url)

# %%
len(tables)
# Out:
# 3

# %%
df= tables[0]

# %%
df
# Out:
#    Rank                 Name          Organization                 Sport  \
# 0     1         Lionel Messi          FC Barcelona  Association football
# 1     2    Cristiano Ronaldo              Al-Nassr  Association football
# 2     3  Patrick Mahomes[e]‡    Kansas City Chiefs     American football
# 3     4           Mike Trout    Los Angeles Angels              Baseball
# 4     5       Canelo Álvarez                 DAZN*                Boxing
# ..  ...                  ...                   ...                   ...
# 94   96         Chris DavisR    Baltimore Orioles*              Baseball
# 95   97       Manny RamírezR       Boston Red Sox*              Baseball
# 96   98           Matt KempR  Los Angeles Dodgers*              Baseball
# 97   99        Dak Prescott‡        Dallas Cowboys     American football
# 98  100    Matthew Stafford‡      Los Angeles Rams     American football
#
#           Length of contract Contract value (USD) Average per year (USD)  \
# ...

# %%
df.to_csv('Sports Contract')
